# %%
#standard import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ls data/bnp
# Out:
# guess_with_mean.csv*  sample_submission.csv*  test.csv*  train.csv*

# %%
train_origin = pd.read_csv('data/bnp/train.csv')
test_origin = pd.read_csv('data/bnp/test.csv')

# %%
train_origin.columns.values
# Out:
# array(['ID', 'target', 'v1', 'v2', 'v3', 'v4', 'v5', 'v6', 'v7', 'v8',
#        'v9', 'v10', 'v11', 'v12', 'v13', 'v14', 'v15', 'v16', 'v17', 'v18',
#        'v19', 'v20', 'v21', 'v22', 'v23', 'v24', 'v25', 'v26', 'v27',
#        'v28', 'v29', 'v30', 'v31', 'v32', 'v33', 'v34', 'v35', 'v36',
#        'v37', 'v38', 'v39', 'v40', 'v41', 'v42', 'v43', 'v44', 'v45',
#        'v46', 'v47', 'v48', 'v49', 'v50', 'v51', 'v52', 'v53', 'v54',
#        'v55', 'v56', 'v57', 'v58', 'v59', 'v60', 'v61', 'v62', 'v63',
#        'v64', 'v65', 'v66', 'v67', 'v68', 'v69', 'v70', 'v71', 'v72',
#        'v73', 'v74', 'v75', 'v76', 'v77', 'v78', 'v79', 'v80', 'v81',
#        'v82', 'v83', 'v84', 'v85', 'v86', 'v87', 'v88', 'v89', 'v90',
#        'v91', 'v92', 'v93', 'v94', 'v95', 'v96', 'v97', 'v98', 'v99',
#        'v100', 'v101', 'v102', 'v103', 'v104', 'v105', 'v106', 'v107',
#        'v108', 'v109', 'v110', 'v111', 'v112', 'v113', 'v114', 'v115',
# ...

# %%
train = train_origin.drop(['ID'], axis=1)

# %%
train.describe()
# Out:
#               target            v1            v2            v4            v5  \
# count  114321.000000  6.448900e+04  6.452500e+04  6.452500e+04  6.569700e+04
# mean        0.761199  1.630686e+00  7.464411e+00  4.145098e+00  8.742359e+00
# std         0.426353  1.082813e+00  2.961676e+00  1.148263e+00  2.036018e+00
# min         0.000000 -9.996497e-07 -9.817614e-07 -6.475929e-07 -5.287068e-07
# 25%         1.000000  9.135798e-01  5.316428e+00  3.487398e+00  7.605918e+00
# 50%         1.000000  1.469550e+00  7.023803e+00  4.205991e+00  8.670867e+00
# 75%         1.000000  2.136128e+00  9.465497e+00  4.833250e+00  9.771353e+00
# max         1.000000  2.000000e+01  2.000000e+01  2.000000e+01  2.000000e+01
#
#                  v6            v7            v8            v9           v10  \
# count  6.448900e+04  6.448900e+04  6.570200e+04  6.447000e+04  1.142370e+05
# mean   2.436402e+00  2.483921e+00  1.496569e+00  9.031859e+00  1.883046e+00
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114321 entries, 0 to 114320
# Columns: 132 entries, target to v131
# dtypes: float64(108), int64(5), object(19)
# memory usage: 116.0+ MB

# %%
#correspondence analysis of v91-v107
#import mca
#mca_df = mca.mca(train.loc[:, ['v91', 'v107']])
pd.crosstab(train.v91, train.v107)  #train['v91'], train['v107']
# Out:
# v107      A      B      C      D      E     F    G
# v91
# A         0      0      0      0  27079     0    0
# B         0  22683      0      0      0     0    0
# C         0      0      0  23157      0     0    0
# D         0      0      0      0      0     0  230
# E         0      0      0      0      0  3206    0
# F     13418      0      0      0      0     0    0
# G         0      0  24545      0      0     0    0

# %%
pd.crosstab(train.v71,train.v75)
# Out:
# v75  A      B  C      D
# v71
# A    1      0  0      0
# B    4  30247  4      0
# C    1   8944  1      1
# D    0      0  1      0
# F    1      1  6  75086
# G    3      0  2      0
# I    7      0  9      0
# K    1      0  0      0
# L    0      0  1      0

# %%
pd.crosstab(train.v79,train.v71)
# Out:
# v71  A     B     C  D      F  G  I  K  L
# v79
# A    0   130    40  0    247  0  0  0  0
# B    1  8135  1400  1  16252  2  8  1  1
# C    0  7389  3189  0  23979  2  2  0  0
# D    0  1286   677  0   3339  0  0  0  0
# E    0  7422  2152  0  15680  0  3  0  0
# F    0   243    26  0    302  0  0  0  0
# G    0     4     0  0      2  0  0  0  0
# H    0   533   233  0   1238  0  0  0  0
# I    0   867   203  0   3491  0  0  0  0
# J    0   427    20  0    486  0  0  0  0
# K    0   752   210  0   3345  0  1  0  0
# L    0     1     0  0      0  0  0  0  0
# M    0   666   299  0   2981  0  0  0  0
# N    0    17     3  0     29  0  0  0  0
# O    0  1152   351  0   1827  0  1  0  0
# P    0   951    31  0   1234  0  1  0  0
# Q    0   257   111  0    637  1  0  0  0
# R    0    23     2  0     25  0  0  0  0

# %%
pd.crosstab(train.v47, train.v110)
# Out:
# v110      A      B     C
# v47
# A        38      0     0
# B         0      0    50
# C         0  55425     0
# D         0      0  3157
# E      5301      0     0
# F      4322      0     0
# G      3946      0     0
# H         0      1     0
# I     39071      0     0
# J      3010      0     0

# %%
#pd.crosstab(train.v10, train.v31)
train.v10.describe()
# Out:
# count    1.142370e+05
# mean     1.883046e+00
# std      1.393979e+00
# min     -9.875317e-07
# 25%      1.050328e+00
# 50%      1.312910e+00
# 75%      2.100657e+00
# max      1.853392e+01
# Name: v10, dtype: float64

# %%
v31map = {'A':1,'B':2,'C':3,'D':4}
plt.scatter(train.v31.fillna('D').map(lambda x:v31map[x]), train.v10.fillna(-1))

# %%
#v72 = v129+v38+v62
pd.Series(train.v72==train.v129+train.v38+train.v62).value_counts()
# Out:
# True    114321
# dtype: int64

# %%
train.v31.describe()
# Out:
# count     110864
# unique         3
# top            A
# freq       88347
# Name: v31, dtype: object
